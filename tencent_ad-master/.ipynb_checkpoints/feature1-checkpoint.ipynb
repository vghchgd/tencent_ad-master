# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import OneHotEncoder,LabelEncoder
from scipy import sparse
from sklearn.model_selection import train_test_split
import scipy.special as special
from sklearn.externals import joblib
import gc, os
import datetime
import pickle

# %%
print ('-------------------------read data------------------------')
print (datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S'))
ad_feature=pd.read_csv('../data/adFeature.csv')
if os.path.exists('../data/userFeature.csv'):
    user_feature=pd.read_csv('../data/userFeature.csv')
else:
    userFeature_data = []
    with open('../data/userFeature.data', 'r') as f:
        for i, line in enumerate(f):
            line = line.strip().split('|')
            userFeature_dict = {}
            for each in line:
                each_list = each.split(' ')
                userFeature_dict[each_list[0]] = ' '.join(each_list[1:])
            userFeature_data.append(userFeature_dict)
            if i % 100000 == 0:
                print(i)
        user_feature = pd.DataFrame(userFeature_data)
        user_feature.to_csv('../data/userFeature.csv', index=False)
        del userFeature_data
print (datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S'))

# %%
sample_feature_data_path = '../data/sample_data/'
raw_data_path = '../data/raw_data/'

# %%
train=pd.read_csv('../data/train.csv')
predict=pd.read_csv('../data/test1.csv')
train.loc[train['label']==-1,'label']=0
predict['label']=-1
data=pd.concat([train,predict])
data=pd.merge(data,ad_feature,on='aid',how='left')
data=pd.merge(data,user_feature,on='uid',how='left')
data=data.fillna('-1')
train = data[train['label']==-1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-907efbb17ad2> in <module>()
#       4 predict['label']=-1
#       5 data=pd.concat([train,predict])
# ----> 6 data=pd.merge(data,ad_feature,on='aid',how='left')
#       7 data=pd.merge(data,user_feature,on='uid',how='left')
#       8 data=data.fillna('-1')
#
# NameError: name 'ad_feature' is not defined

# %%
data = pd.read_csv('../data/sample_train.csv')
data.fillna(value='-1', inplace=True)
y = data.pop('label')
train_x, test_x, train_y, test_y = train_test_split( data, y, test_size = 0.2, random_state = 2018)
test_y[[i for i in test_y.index]] = [-1 for _ in range(test_y.shape[0])]
train = pd.concat([train_x, train_y], axis=1)

test = pd.concat([test_x, test_y], axis=1)
data = pd.concat([train, test])
data = data.reset_index(drop=True)

# %%
drop_feature = ['appIdAction','appIdInstall','interest3','interest4','kw3','topic3']
data.drop(drop_feature, axis=1,inplace=True)

# %%
class BayesianSmoothing(object):
    def __init__(self, alpha, beta):
        self.alpha = alpha
        self.beta = beta

    def sample(self, alpha, beta, num, imp_upperbound):
        sample = np.random.beta(alpha, beta, num)
        I = []
        C = []
        for clk_rt in sample:
            imp = random.random() * imp_upperbound
            imp = imp_upperbound
            clk = imp * clk_rt
            I.append(imp)
            C.append(clk)
        return I, C

    def update(self, imps, clks, iter_num, epsilon):
        for i in range(iter_num):
            new_alpha, new_beta = self.__fixed_point_iteration(imps, clks, self.alpha, self.beta)
            if abs(new_alpha - self.alpha) < epsilon and abs(new_beta - self.beta) < epsilon:
                break
            self.alpha = new_alpha
            self.beta = new_beta

    def __fixed_point_iteration(self, imps, clks, alpha, beta):
        numerator_alpha = 0.0
        numerator_beta = 0.0
        denominator = 0.0

        for i in range(len(imps)):
            numerator_alpha += (special.digamma(clks[i] + alpha) - special.digamma(alpha))
            numerator_beta += (special.digamma(imps[i] - clks[i] + beta) - special.digamma(beta))
            denominator += (special.digamma(imps[i] + alpha + beta) - special.digamma(alpha + beta))

        return alpha * (numerator_alpha / denominator), beta * (numerator_beta / denominator)

# %%
def gen_features():

    # test = load_pickle(raw_data_path + 'sample_test.pkl')
    print("uid_adCount")
    temp = train.groupby('uid')['aid'].count().reset_index()
    temp.columns=['uid','uid_adCount']
    temp.to_csv(sample_feature_data_path+'uid_adCount.csv',index=False)

    for feat_1 in ['creativeId', 'aid', 'advertiserId','campaignId','adCategoryId',
                   'education', 'LBS', 'consumptionAbility','marriageStatus','age','house']:
        gc.collect()
        temp = train[[feat_1, 'label']]
        count = temp.groupby([feat_1]).apply(lambda x: x['label'].count()).reset_index(
            name=feat_1 + '_all')
        count1 = temp.groupby([feat_1]).apply(lambda x: x['label'].sum()).reset_index(
            name=feat_1 + '_1')
        count[feat_1 + '_1'] = count1[feat_1 + '_1']
        count.fillna(value=-1, inplace=True)

        count.to_csv(sample_feature_data_path + '%s.csv' % (feat_1), index=False)
        print(feat_1, ' over')


    for feat_1,feat_2 in [('creativeId','LBS'),('creativeId','age'),('creativeId','gender'),
                          ('creativeId','education'),('creativeId','marriageStatus'),
                          ('creativeId','house'),('creativeId','consumptionAbility'),#('creativeId','uid'),
                          ('aid', 'LBS'), ('aid', 'age'), ('aid', 'gender'),
                          ('aid', 'education'), ('aid', 'marriageStatus'),
                          ('aid', 'house'),('aid','consumptionAbility'),#('aid','uid'),
                          ('advertiserId', 'LBS'), ('advertiserId', 'age'), ('advertiserId', 'gender'),
                          ('advertiserId', 'education'), ('advertiserId', 'marriageStatus'),
                          ('advertiserId', 'house'),('advertiserId','consumptionAbility'),#('advertiserId', 'uid'),
                          ('campaignId', 'LBS'), ('campaignId', 'age'), ('campaignId', 'gender'),
                          ('campaignId', 'education'), ('campaignId', 'marriageStatus'),
                          ('campaignId', 'house'),('campaignId','consumptionAbility'),#('campaignId', 'uid'),
                          ('adCategoryId', 'LBS'), ('adCategoryId', 'age'), ('adCategoryId', 'gender'),
                          ('adCategoryId', 'education'), ('adCategoryId', 'marriageStatus'),
                          ('adCategoryId', 'house'),('adCategoryId','consumptionAbility'),#('adCategoryId', 'uid')
                          ]:
        gc.collect()

        if os.path.exists(sample_feature_data_path + '%s.csv' % (feat_1+'_'+feat_2 )):
            print('found  ' + sample_feature_data_path + '%s.csv' % (feat_1+'_'+feat_2 ) )
        else:
            print('generate ' + sample_feature_data_path + '%s.csv' % (feat_1+'_'+feat_2 ) )

            temp = train[[feat_1, feat_2, 'label']]
            count = temp.groupby([feat_1,feat_2]).apply(lambda x: x['label'].count()).reset_index(
                name=feat_1 + '_' + feat_2 + '_all')
            count1 = temp.groupby([feat_1, feat_2]).apply(lambda x: x['label'].sum()).reset_index(
                name=feat_1 + '_' + feat_2 + '_1')
            count[feat_1 + '_' + feat_2 + '_1'] = count1[feat_1 + '_' + feat_2 + '_1']
            count.fillna(value=0, inplace=True)

            count.to_csv(sample_feature_data_path + '%s.csv' % (feat_1+'_'+feat_2), index=False)
            print(feat_1, feat_2, ' over')

# %%
def add_AllFeatures(data):


    count = pd.read_csv(sample_feature_data_path + 'uid_adCount.csv')
    data = data.merge(count, how='left', on='uid')
    data.fillna(value=0, inplace=True)
    print ('uid over')

    for feat_1 in ['creativeId', 'aid', 'advertiserId', 'campaignId', 'adCategoryId',
                   'education', 'LBS', 'consumptionAbility', 'marriageStatus', 'age', 'house']:
        count = pd.read_csv(sample_feature_data_path + '%s.csv' % (feat_1))
        bs = BayesianSmoothing(1, 1)
        bs.update(count[feat_1 + '_all'].values, count[feat_1 + '_1'].values, 1000, 0.001)
        count[feat_1 + '_ctr'] = (count[feat_1 + '_1'] + bs.alpha) / (
                count[feat_1 + '_all'] + bs.alpha + bs.beta)
        count[feat_1 + '_ctr'] = count[feat_1 + '_ctr'].apply(lambda x: float('%.6f' % x))
        count.drop([feat_1 + '_1', feat_1 + '_all'], axis=1, inplace=True)
#         count[feat_1  + '_ctr'] = 100 * (count[feat_1 + '_1'] +0.0001) / (
#             count[feat_1  + '_all'] + 0.0001)
#         count[feat_1 + '_ctr'] = count[feat_1 + '_ctr'].apply(lambda x: float('%.6f' % x))
#         count.drop([feat_1 +  '_1', feat_1 +  '_all'], axis=1, inplace=True)
        data = data.merge(count, how='left', on=feat_1)
#         data.fillna(value=bs.alpha / (bs.alpha + bs.beta), inplace=True)
        data.fillna(value=0, inplace=True)

        print ("concat " + feat_1 + "over")

    for feat_1, feat_2 in [('creativeId', 'LBS'), ('creativeId', 'age'), ('creativeId', 'gender'),
                           ('creativeId', 'education'), ('creativeId', 'marriageStatus'),
                           ('creativeId', 'house'), ('creativeId', 'consumptionAbility'),  # ('creativeId','uid'),
                           ('aid', 'LBS'), ('aid', 'age'), ('aid', 'gender'),
                           ('aid', 'education'), ('aid', 'marriageStatus'),
                           ('aid', 'house'), ('aid', 'consumptionAbility'),  # ('aid','uid'),
                           ('advertiserId', 'LBS'), ('advertiserId', 'age'), ('advertiserId', 'gender'),
                           ('advertiserId', 'education'), ('advertiserId', 'marriageStatus'),
                           ('advertiserId', 'house'), ('advertiserId', 'consumptionAbility'),
                           # ('advertiserId', 'uid'),
                           ('campaignId', 'LBS'), ('campaignId', 'age'), ('campaignId', 'gender'),
                           ('campaignId', 'education'), ('campaignId', 'marriageStatus'),
                           ('campaignId', 'house'), ('campaignId', 'consumptionAbility'),  # ('campaignId', 'uid'),
                           ('adCategoryId', 'LBS'), ('adCategoryId', 'age'), ('adCategoryId', 'gender'),
                           ('adCategoryId', 'education'), ('adCategoryId', 'marriageStatus'),
                           ('adCategoryId', 'house'), ('adCategoryId', 'consumptionAbility'),  # ('adCategoryId', 'uid')
                           ]:
        gc.collect()
        count = pd.read_csv(sample_feature_data_path + '%s.csv' % (feat_1 + '_' + feat_2))
        bs = BayesianSmoothing(1, 1)
        bs.update(count[feat_1 + '_' + feat_2 + '_all'].values, count[feat_1 + '_' + feat_2 + '_1'].values, 1000, 0.001)
        count[feat_1 + '_' + feat_2 + '_ctr'] = (count[feat_1 + '_' + feat_2 + '_1'] + bs.alpha) / (
                count[feat_1 + '_' + feat_2 + '_all'] + bs.alpha + bs.beta)
        count[feat_1 + '_' + feat_2 + '_ctr'] = count[feat_1 + '_' + feat_2 + '_ctr'].apply(lambda x: float('%.6f' % x))

        count.drop([feat_1 + '_' + feat_2 + '_1', feat_1 + '_' + feat_2 + '_all'], axis=1, inplace=True)
#         count[feat_1 + '_' + feat_2 + '_ctr'] = 100 * (count[feat_1 + '_' + feat_2 + '_1'] +0.0001) / (
#             count[feat_1 + '_' + feat_2 + '_all'] + 0.0001)
#         count[feat_1 + '_' + feat_2 + '_ctr'] = count[feat_1 + '_' + feat_2 + '_ctr'].apply(lambda x: float('%.6f' % x))
#         count.drop([feat_1 + '_' + feat_2 + '_1', feat_1 + '_' + feat_2 + '_all'], axis=1, inplace=True)
        data = data.merge(count, how='left', on=[feat_1, feat_2])
#         data.fillna(value=bs.alpha / (bs.alpha + bs.beta), inplace=True)
        data.fillna(value=0, inplace=True)

        print("concat " + feat_1 +'_' + feat_2+ " over")

    ct_train = data['ct'].values
    ct_train = [m.split(' ') for m in ct_train]
    ct_trains = []
    for i in ct_train:
        index = [0, 0, 0, 0, 0]
        for j in i:
            index[int(j)] = 1
        ct_trains.append(index)

    ct_feat = pd.DataFrame(ct_trains, columns=['ct_{}'.format(i) for i in range(5)])
    data = pd.concat([data, ct_feat], axis=1)
        
    output = open(raw_data_path+ "sample_data_smooth.pkl", 'wb')    
    pickle.dump(data, output, protocol=4)
    output.close()
    del data
    gc.collect()

# %%
gen_features()
add_AllFeatures(data)
# Out:
# uid_adCount
# creativeId  over
# aid  over
# advertiserId  over
# campaignId  over
# adCategoryId  over
# education  over
# LBS  over
# consumptionAbility  over
# marriageStatus  over
# age  over
# house  over
# found  ../data/sample_data/creativeId_LBS.csv
# found  ../data/sample_data/creativeId_age.csv
# found  ../data/sample_data/creativeId_gender.csv
# found  ../data/sample_data/creativeId_education.csv
# found  ../data/sample_data/creativeId_marriageStatus.csv
# found  ../data/sample_data/creativeId_house.csv
# found  ../data/sample_data/creativeId_consumptionAbility.csv
# found  ../data/sample_data/aid_LBS.csv
# found  ../data/sample_data/aid_age.csv
# found  ../data/sample_data/aid_gender.csv
# found  ../data/sample_data/aid_education.csv
# found  ../data/sample_data/aid_marriageStatus.csv
# found  ../data/sample_data/aid_house.csv
# found  ../data/sample_data/aid_consumptionAbility.csv
# found  ../data/sample_data/advertiserId_LBS.csv
# found  ../data/sample_data/advertiserId_age.csv
# found  ../data/sample_data/advertiserId_gender.csv
# found  ../data/sample_data/advertiserId_education.csv
# found  ../data/sample_data/advertiserId_marriageStatus.csv
# found  ../data/sample_data/advertiserId_house.csv
# found  ../data/sample_data/advertiserId_consumptionAbility.csv
# found  ../data/sample_data/campaignId_LBS.csv
# found  ../data/sample_data/campaignId_age.csv
# found  ../data/sample_data/campaignId_gender.csv
# found  ../data/sample_data/campaignId_education.csv
# found  ../data/sample_data/campaignId_marriageStatus.csv
# found  ../data/sample_data/campaignId_house.csv
# found  ../data/sample_data/campaignId_consumptionAbility.csv
# found  ../data/sample_data/adCategoryId_LBS.csv
# found  ../data/sample_data/adCategoryId_age.csv
# found  ../data/sample_data/adCategoryId_gender.csv
# found  ../data/sample_data/adCategoryId_education.csv
# found  ../data/sample_data/adCategoryId_marriageStatus.csv
# found  ../data/sample_data/adCategoryId_house.csv
# found  ../data/sample_data/adCategoryId_consumptionAbility.csv
# uid over
# concat creativeIdover
# concat aidover
# concat advertiserIdover
# concat campaignIdover
# concat adCategoryIdover
# concat educationover
# concat LBSover
# concat consumptionAbilityover
# concat marriageStatusover
# concat ageover
# concat houseover
# concat creativeId_LBS over
# concat creativeId_age over
# concat creativeId_gender over
# concat creativeId_education over
# concat creativeId_marriageStatus over
# concat creativeId_house over
# concat creativeId_consumptionAbility over
# concat aid_LBS over
# concat aid_age over
# concat aid_gender over
# concat aid_education over
# concat aid_marriageStatus over
# concat aid_house over
# concat aid_consumptionAbility over
# concat advertiserId_LBS over
# concat advertiserId_age over
# concat advertiserId_gender over
# concat advertiserId_education over
# concat advertiserId_marriageStatus over
# concat advertiserId_house over
# concat advertiserId_consumptionAbility over
# concat campaignId_LBS over
# concat campaignId_age over
# concat campaignId_gender over
# concat campaignId_education over
# concat campaignId_marriageStatus over
# concat campaignId_house over
# concat campaignId_consumptionAbility over
# concat adCategoryId_LBS over
# concat adCategoryId_age over
# concat adCategoryId_gender over
# concat adCategoryId_education over
# concat adCategoryId_marriageStatus over
# concat adCategoryId_house over
# concat adCategoryId_consumptionAbility over

# %%
f = open(raw_data_path + 'sample_data_smooth.pkl', 'rb')
train = pickle.load(f)
f.close()
# train.drop('index', axis=1, inplace=True)

# %%
train.head().T
# Out:
#                                                                                      0  \
# aid                                                                               1119
# uid                                                                           59833340
# advertiserId                                                                      3993
# campaignId                                                                       63752
# creativeId                                                                      798752
# creativeSize                                                                        59
# adCategoryId                                                                        10
# productId                                                                        19256
# productType                                                                         11
# LBS                                                                                 72
# age                                                                                  4
# carrier                                                                              0
# consumptionAbility                                                                   1
# ct                                                                                 3 1
# education                                                                            2
# gender                                                                               1
# house                                                                               -1
# interest1                            93 70 77 109 98 75 4 69 10 8 29 49 27 6 19 46 ...
# interest2                                                                      24 9 30
# interest5                                                                           -1
# kw1                                                  465998 171741 602557 271833 10358
# kw2                                                     87384 43134 81211 44360 107490
# marriageStatus                                                                      11
# os                                                                                   1
# topic1                                                         9324 5935 9158 4305 644
# topic2                                                        9513 8960 9066 5655 4431
# label                                                                                0
# uid_adCount                                                                          1
# creativeId_ctr                                                                 4.66901
# aid_ctr                                                                        4.66901
# ...                                                                                ...
# aid_education_ctr                                                              6.90074
# aid_marriageStatus_ctr                                                         4.27961
# aid_house_ctr                                                                  4.79288
# aid_consumptionAbility_ctr                                                     4.13712
# advertiserId_LBS_ctr                                                           6.52194
# advertiserId_age_ctr                                                           3.87229
# advertiserId_gender_ctr                                                        4.77149
# advertiserId_education_ctr                                                     6.78942
# advertiserId_marriageStatus_ctr                                                4.59519
# advertiserId_house_ctr                                                         4.80649
# advertiserId_consumptionAbility_ctr                                            4.15369
# campaignId_LBS_ctr                                                             6.97696
# campaignId_age_ctr                                                             3.52942
# campaignId_gender_ctr                                                          4.65839
# campaignId_education_ctr                                                       6.83454
# campaignId_marriageStatus_ctr                                                  4.33163
# campaignId_house_ctr                                                           4.71888
# campaignId_consumptionAbility_ctr                                              4.01584
# adCategoryId_LBS_ctr                                                            8.1819
# adCategoryId_age_ctr                                                           4.44846
# adCategoryId_gender_ctr                                                        4.84295
# adCategoryId_education_ctr                                                      5.6648
# adCategoryId_marriageStatus_ctr                                                4.89822
# adCategoryId_house_ctr                                                         4.92495
# adCategoryId_consumptionAbility_ctr                                            4.64619
# ct_0                                                                                 0
# ct_1                                                                                 1
# ct_2                                                                                 0
# ct_3                                                                                 1
# ct_4                                                                                 0
#
#                                                                   1  \
# aid                                                             411
# uid                                                        79728744
# advertiserId                                                   9106
# campaignId                                                   163120
# creativeId                                                   220179
# creativeSize                                                     79
# adCategoryId                                                     21
# productId                                                         0
# productType                                                       4
# LBS                                                             112
# age                                                               2
# carrier                                                           0
# consumptionAbility                                                0
# ct                                                                0
# education                                                         0
# gender                                                            0
# house                                                            -1
# interest1                                                        -1
# interest2                                                      4 17
# interest5                                                        -1
# kw1                                                              -1
# kw2                                  76242 29946 21380 113547 90631
# marriageStatus                                                    0
# os                                                                0
# topic1                                                           -1
# topic2                                      423 2438 5002 9625 2485
# label                                                             0
# uid_adCount                                                       1
# creativeId_ctr                                              4.67915
# aid_ctr                                                     4.67915
# ...                                                             ...
# aid_education_ctr                                           20.0002
# aid_marriageStatus_ctr                                      5.71432
# aid_house_ctr                                               4.65897
# aid_consumptionAbility_ctr                                  4.80308
# advertiserId_LBS_ctr                                        2.12776
# advertiserId_age_ctr                                        6.16798
# advertiserId_gender_ctr                                     5.71455
# advertiserId_education_ctr                                  15.2544
# advertiserId_marriageStatus_ctr                             4.83873
# advertiserId_house_ctr                                      4.53139
# advertiserId_consumptionAbility_ctr                         4.28878
# campaignId_LBS_ctr                                         0.000156
# campaignId_age_ctr                                          6.05578
# campaignId_gender_ctr                                       8.69605
# campaignId_education_ctr                                    20.0002
# campaignId_marriageStatus_ctr                               5.71432
# campaignId_house_ctr                                        4.65897
# campaignId_consumptionAbility_ctr                           4.80308
# adCategoryId_LBS_ctr                                         5.1887
# adCategoryId_age_ctr                                        6.91299
# adCategoryId_gender_ctr                                     9.09112
# adCategoryId_education_ctr                                    15.19
# adCategoryId_marriageStatus_ctr                             5.81007
# adCategoryId_house_ctr                                      4.78937
# adCategoryId_consumptionAbility_ctr                         4.50317
# ct_0                                                              1
# ct_1                                                              0
# ct_2                                                              0
# ct_3                                                              0
# ct_4                                                              0
#
#                                                                                      2  \
# aid                                                                                411
# uid                                                                           26092769
# advertiserId                                                                      9106
# campaignId                                                                      163120
# creativeId                                                                      220179
# creativeSize                                                                        79
# adCategoryId                                                                        21
# productId                                                                            0
# productType                                                                          4
# LBS                                                                                273
# age                                                                                  2
# carrier                                                                              1
# consumptionAbility                                                                   1
# ct                                                                                 3 1
# education                                                                            6
# gender                                                                               1
# house                                                                               -1
# interest1                            70 86 118 47 75 76 8 29 49 2 42 18 17 9 56 36 ...
# interest2                                                                           -1
# interest5                            72 92 116 101 13 105 47 109 8 30 50 6 42 76 75...
# kw1                                                       411962 2268 604 40456 363065
# kw2                                                     18185 53464 80417 85039 115512
# marriageStatus                                                                      10
# os                                                                                   2
# topic1                                                        8822 9205 7684 4902 9826
# topic2                                                          7674 9772 5732 2091 46
# label                                                                                0
# uid_adCount                                                                          1
# creativeId_ctr                                                                 4.67915
# aid_ctr                                                                        4.67915
# ...                                                                                ...
# aid_education_ctr                                                              4.22964
# aid_marriageStatus_ctr                                                         4.77022
# aid_house_ctr                                                                  4.65897
# aid_consumptionAbility_ctr                                                     4.40853
# advertiserId_LBS_ctr                                                          0.000588
# advertiserId_age_ctr                                                           6.16798
# advertiserId_gender_ctr                                                         5.2791
# advertiserId_education_ctr                                                      3.4483
# advertiserId_marriageStatus_ctr                                                4.62428
# advertiserId_house_ctr                                                         4.53139
# advertiserId_consumptionAbility_ctr                                            4.36843
# campaignId_LBS_ctr                                                            0.000769
# campaignId_age_ctr                                                             6.05578
# campaignId_gender_ctr                                                          5.22766
# campaignId_education_ctr                                                       4.22964
# campaignId_marriageStatus_ctr                                                  4.77022
# campaignId_house_ctr                                                           4.65897
# campaignId_consumptionAbility_ctr                                              4.40853
# adCategoryId_LBS_ctr                                                           1.75456
# adCategoryId_age_ctr                                                           6.91299
# adCategoryId_gender_ctr                                                        4.79017
# adCategoryId_education_ctr                                                           4
# adCategoryId_marriageStatus_ctr                                                4.81853
# adCategoryId_house_ctr                                                         4.78937
# adCategoryId_consumptionAbility_ctr                                            4.48498
# ct_0                                                                                 0
# ct_1                                                                                 1
# ct_2                                                                                 0
# ct_3                                                                                 1
# ct_4                                                                                 0
#
#                                                                                      3  \
# aid                                                                               2031
# uid                                                                           23276560
# advertiserId                                                                     83042
# campaignId                                                                      280832
# creativeId                                                                      425385
# creativeSize                                                                        22
# adCategoryId                                                                        70
# productId                                                                            0
# productType                                                                          4
# LBS                                                                                 27
# age                                                                                  2
# carrier                                                                              1
# consumptionAbility                                                                   1
# ct                                                                                 3 1
# education                                                                            2
# gender                                                                               2
# house                                                                               -1
# interest1                                                                           -1
# interest2                                   66 22 79 1 46 70 6 21 28 43 65 54 10 29 35
# interest5                            104 31 131 78 109 8 30 6 42 76 62 59 64 96 51 ...
# kw1                                                                                 -1
# kw2                                                     19007 56505 50037 121094 85423
# marriageStatus                                                                       0
# os                                                                                   2
# topic1                                                                              -1
# topic2                                                        9018 1471 1933 7662 7009
# label                                                                                1
# uid_adCount                                                                          1
# creativeId_ctr                                                                 5.86539
# aid_ctr                                                                        5.86539
# ...                                                                                ...
# aid_education_ctr                                                              7.16421
# aid_marriageStatus_ctr                                                         14.2863
# aid_house_ctr                                                                  5.91018
# aid_consumptionAbility_ctr                                                      5.3226
# advertiserId_LBS_ctr                                                           4.76236
# advertiserId_age_ctr                                                           8.21116
# advertiserId_gender_ctr                                                        5.81396
# advertiserId_education_ctr                                                     7.16421
# advertiserId_marriageStatus_ctr                                                14.2863
# advertiserId_house_ctr                                                         5.91018
# advertiserId_consumptionAbility_ctr                                             5.3226
# campaignId_LBS_ctr                                                             4.76236
# campaignId_age_ctr                                                             8.21116
# campaignId_gender_ctr                                                          5.81396
# campaignId_education_ctr                                                       7.16421
# campaignId_marriageStatus_ctr                                                  14.2863
# campaignId_house_ctr                                                           5.91018
# campaignId_consumptionAbility_ctr                                               5.3226
# adCategoryId_LBS_ctr                                                           4.76236
# adCategoryId_age_ctr                                                           8.21116
# adCategoryId_gender_ctr                                                        5.81396
# adCategoryId_education_ctr                                                     7.16421
# adCategoryId_marriageStatus_ctr                                                14.2863
# adCategoryId_house_ctr                                                         5.91018
# adCategoryId_consumptionAbility_ctr                                             5.3226
# ct_0                                                                                 0
# ct_1                                                                                 1
# ct_2                                                                                 0
# ct_3                                                                                 1
# ct_4                                                                                 0
#
#                                                                        4
# aid                                                                  692
# uid                                                              5236004
# advertiserId                                                        6946
# campaignId                                                        296367
# creativeId                                                        455396
# creativeSize                                                          59
# adCategoryId                                                          24
# productId                                                           3794
# productType                                                           11
# LBS                                                                  902
# age                                                                    2
# carrier                                                                1
# consumptionAbility                                                     1
# ct                                                                   1 3
# education                                                              2
# gender                                                                 1
# house                                                                  1
# interest1                            12 47 69 6 17 9 56 112 116 36 11 38
# interest2                                                    58 24 49 30
# interest5                                 92 37 13 47 6 9 75 89 46 10 35
# kw1                                     562294 77632 468512 274933 23934
# kw2                                       102474 48733 82720 44999 56438
# marriageStatus                                                        10
# os                                                                     2
# topic1                                            4771 6051 103 574 8013
# topic2                                          5566 7724 4518 2920 8521
# label                                                                  0
# uid_adCount                                                            1
# creativeId_ctr                                                   5.11846
# aid_ctr                                                          5.11846
# ...                                                                  ...
# aid_education_ctr                                                4.66322
# aid_marriageStatus_ctr                                           5.23284
# aid_house_ctr                                                     4.7194
# aid_consumptionAbility_ctr                                       5.57824
# advertiserId_LBS_ctr                                            0.000435
# advertiserId_age_ctr                                             4.17202
# advertiserId_gender_ctr                                          4.88933
# advertiserId_education_ctr                                       4.49845
# advertiserId_marriageStatus_ctr                                  4.91468
# advertiserId_house_ctr                                           4.72194
# advertiserId_consumptionAbility_ctr                              5.11811
# campaignId_LBS_ctr                                              0.000435
# campaignId_age_ctr                                               4.17202
# campaignId_gender_ctr                                            4.88933
# campaignId_education_ctr                                         4.49845
# campaignId_marriageStatus_ctr                                    4.91468
# campaignId_house_ctr                                             4.72194
# campaignId_consumptionAbility_ctr                                5.11811
# adCategoryId_LBS_ctr                                             3.33366
# adCategoryId_age_ctr                                             4.22692
# adCategoryId_gender_ctr                                          5.03137
# adCategoryId_education_ctr                                       4.76788
# adCategoryId_marriageStatus_ctr                                  4.88287
# adCategoryId_house_ctr                                           5.09119
# adCategoryId_consumptionAbility_ctr                              5.00479
# ct_0                                                                   0
# ct_1                                                                   1
# ct_2                                                                   0
# ct_3                                                                   1
# ct_4                                                                   0
#
# [79 rows x 5 columns]

# %%
def func(x1, x2):
    return str(x1)+'_'+str(x2)

def func2(x1, x2, x3):
    return str(x1)+'_'+str(x2)+"_"+str(x3)

# %%
def cross_feat(train, fea1, fea2):
    value = list(map(func, train[fea1], train[fea2]))
#     dummies = pd.get_dummies(value, prefix='{}_{}'.format(fea1, fea2))
    feat = pd.Series(value, name='{}_{}'.format(fea1, fea2))
    return feat

def cross_3feat(train, fea1, fea2, fea3):
    value = list(map(func2, train[fea1], train[fea2], train[fea3]))
    feat = pd.Series(value, name='{}_{}_{}'.format(fea1, fea2, fea3))
    return feat

# %%
cross_2fea = [('productType', 'creativeSize'),
 ('productType', 'marriageStatus'),
 ('productType', 'os'),
 ('age', 'education'),
 ('age', 'carrier'),
 ('education', 'marriageStatus'),
 ('education', 'carrier'),
 ('creativeSize', 'carrier'),
 ('consumptionAbility', 'carrier'),
 ('marriageStatus', 'os')
 ]
cross_3fea = [('education', 'marriageStatus', 'productType'),('education', 'marriageStatus', 'carrier'),  ('education', 'age', 'carrier')]

# %%
one_hot_feature=['age','carrier','consumptionAbility','education','gender','house','os','ct','marriageStatus','advertiserId','campaignId', 'creativeId',
       'adCategoryId', 'productId', 'productType']

# %%
for fea1, fea2, fea3 in cross_3fea:
    fea1_fea2_fea3 = cross_3feat(train, fea1, fea2, fea3)
    train[fea1_fea2_fea3.name] = fea1_fea2_fea3
#     print(fea1_fea2_fea3.name,train[fea1_fea2_fea3.name].value_counts().shape[0])
    one_hot_feature.append((fea1_fea2_fea3.name))
for fea1, fea2 in cross_2fea:
    fea1_fea2 = cross_feat(train, fea1, fea2)
    train[fea1_fea2.name] = fea1_fea2
#     print(fea1_fea2.name,train[fea1_fea2.name].value_counts().shape[0])
    one_hot_feature.append(fea1_fea2.name)

# %%
train.shape
# Out:
# (87988, 92)

# %%
for i in data.shape
# Out:
# (87988, 92)

# %%
for feature in one_hot_feature:
    try:
        data[feature] = LabelEncoder().fit_transform(data[feature].apply(int))
    except:
        data[feature] = LabelEncoder().fit_transform(data[feature])

# %%
train=data[data.label!=-1]
train_y=train.pop('label')
test=data[data.label==-1]

# %%
def add_noise(series, noise_level):
    return series * (1 + noise_level * np.random.randn(len(series)))

def target_encode(trn_series=None,
                  tst_series=None,
                  target=None,
                  min_samples_leaf=1,
                  smoothing=1,
                  noise_level=0):
    """
    Smoothing is computed like in the following paper by Daniele Micci-Barreca
    https://kaggle2.blob.core.windows.net/forum-message-attachments/225952/7441/high%20cardinality%20categoricals.pdf
    trn_series : training categorical feature as a pd.Series
    tst_series : test categorical feature as a pd.Series
    target : target data as a pd.Series
    min_samples_leaf (int) : minimum samples to take category average into account
    smoothing (int) : smoothing effect to balance categorical average vs prior
    """
    assert len(trn_series) == len(target)
    assert trn_series.name == tst_series.name
    temp = pd.concat([trn_series, target], axis=1)
    # Compute target mean
    averages = temp.groupby(by=trn_series.name)[target.name].agg(["mean", "count"])
    # Compute smoothing
    smoothing = 1 / (1 + np.exp(-(averages["count"] - min_samples_leaf) / smoothing))
    # Apply average function to all target data
    prior = target.mean()
    # The bigger the count the less full_avg is taken into account
    averages[target.name] = prior * (1 - smoothing) + averages["mean"] * smoothing
    averages.drop(["mean", "count"], axis=1, inplace=True)
    # Apply averages to trn and tst series
    ft_trn_series = pd.merge(
        trn_series.to_frame(trn_series.name),
        averages.reset_index().rename(columns={'index': target.name, target.name: 'average'}),
        on=trn_series.name,
        how='left')['average'].rename(trn_series.name + '_mean').fillna(prior)
    # pd.merge does not keep the index so restore it
    ft_trn_series.index = trn_series.index
    ft_tst_series = pd.merge(
        tst_series.to_frame(tst_series.name),
        averages.reset_index().rename(columns={'index': target.name, target.name: 'average'}),
        on=tst_series.name,
        how='left')['average'].rename(trn_series.name + '_mean').fillna(prior)
    # pd.merge does not keep the index so restore it
    ft_tst_series.index = tst_series.index
    return add_noise(ft_trn_series, noise_level), add_noise(ft_tst_series, noise_level)

# %%
train_encoded, test_encoded = target_encode(trn_series=train["LBS"], tst_series=test["LBS"],
                                target=train_y,
                                min_samples_leaf=100,
                                smoothing=10,
                                noise_level=0.01)
train['LBS_enc'] = train_encoded
train.drop('LBS', axis=1, inplace=True)
test['LBS_enc'] = test_encoded
test.drop('LBS', axis=1, inplace=True)
# train_encoded.to_csv(raw_data_path + 'train_encoded.csv', index=False)
# test_encoded.to_csv(raw_data_path + 'test_encoded.csv', index=False)
# Out:
# /root/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /root/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /root/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /root/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
vector_feature= ['interest1','interest2', 'interest5', 'kw1', 'kw2', 'topic1', 'topic2']

# %%
fea_list = []
for i in train.columns:
    if i not in one_hot_feature and i not in vector_feature and i not in ['aid', 'uid']: 
        fea_list.append(i)

# %%
train_x = train[fea_list].values
test_x = test[fea_list].values


oc_encoder = OneHotEncoder()
for feature in one_hot_feature:
    print (feature)
    oc_encoder.fit(data[feature].values.reshape(-1, 1))
    train_a=oc_encoder.transform(train[feature].values.reshape(-1, 1))
    test_a = oc_encoder.transform(test[feature].values.reshape(-1, 1))
    train_x = sparse.hstack((train_x, train_a))
    test_x = sparse.hstack((test_x, test_a))
print('one-hot prepared !')
# Out:
# age
# carrier
# consumptionAbility
# education
# gender
# house
# os
# ct
# marriageStatus
# advertiserId
# campaignId
# creativeId
# adCategoryId
# productId
# productType
# education_marriageStatus_productType
# education_marriageStatus_carrier
# education_age_carrier
# productType_creativeSize
# productType_marriageStatus
# productType_os
# age_education
# age_carrier
# education_marriageStatus
# education_carrier
# creativeSize_carrier
# consumptionAbility_carrier
# marriageStatus_os
# one-hot prepared !

# %%
train_x.shape
# Out:
# (70390, 2119)

# %%
cv=CountVectorizer(min_df=0.0009)
for feature in vector_feature:
    cv.fit(data[feature])
    train_a = cv.transform(train[feature])
    test_a = cv.transform(test[feature])
    train_x = sparse.hstack((train_x, train_a))
    test_x = sparse.hstack((test_x, test_a))
print('cv prepared !')
print (datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# cv prepared !
# 2018-05-17 11:04:06

# %%
train_y.to_csv('../data/train_y,csv', index=False)
sparse.save_npz('../data/train_x.npz', train_x)
sparse.save_npz('../data/test_x.npz', test_x)
